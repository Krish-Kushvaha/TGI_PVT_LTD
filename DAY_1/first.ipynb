# %%
name = "Krish Kushvaha"
age = "19"
city = "Anand"
goal = "Data Scientist"

print("NAME :", name)
print("AGE :", age)
print("CITY :", city)
print("GOAL :", goal)
# Out:
# NAME : Krish Kushvaha
# AGE : 19
# CITY : Anand
# GOAL : Data Scientist

# %%
name = "Krish Kushvaha"
age = "19"
city = "Anand"
goal = "Data Scientist"

print(f"NAME : {name}")
print(f"AGE : {age}")
print(f"CITY : {city}")
print(f"GOAL : {goal}")
# Out:
# NAME : Krish Kushvaha
# AGE : 19
# CITY : Anand
# GOAL : Data Scientist
